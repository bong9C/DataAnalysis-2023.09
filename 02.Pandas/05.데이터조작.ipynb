# %% [markdown]
# ### 2.5 데이터프레임 데이터 조작

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - 데이터 갯수 세기:count()

# %%
np.random.seed(2)
df = pd.DataFrame(np.random.randint(5, size=(4, 4)), dtype=float)
df.iloc[2, 3] = np.nan
df
# Out:
#      0    1    2    3
# 0  0.0  0.0  3.0  2.0
# 1  3.0  0.0  2.0  1.0
# 2  3.0  2.0  4.0  NaN
# 3  4.0  3.0  4.0  2.0

# %%
df.count()      # 열 별로 NaN이 아닌 값의 갯수 세기
# Out:
# 0    4
# 1    4
# 2    4
# 3    3
# dtype: int64

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.tail(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 888         0       3  female   NaN      1      2  23.45        S  Third
# 889         1       1    male  26.0      0      0  30.00        C  First
# 890         0       3    male  32.0      0      0   7.75        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# ![Alt text](image-3.png)

# %%
titanic.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %% [markdown]
# - 카테고리값 세기: value_counts()

# %%
titanic['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
titanic.embark_town.value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %% [markdown]
# - 정렬: sort_values(),sort_index()

# %%
np.random.seed(2023)
df = pd.DataFrame(np.random.randint(40, 101, size=(4, 5)),
                  index=list('abcd'), columns=list('VWXYZ'))
df
# Out:
#     V   W   X   Y   Z
# a  63  65  46  95  73
# b  68  43  92  92  62
# c  77  72  62  57  87
# d  93  87  53  79  45

# %%
# W 칼럼 오름차순 기준
df.sort_values(by='W')
# Out:
#     V   W   X   Y   Z
# b  68  43  92  92  62
# a  63  65  46  95  73
# c  77  72  62  57  87
# d  93  87  53  79  45

# %%
# Y 컬럼 내림차순 기준, Y 컬럼에 동일한 값이 있으면 Z 컬럼의 내림차순
df2 = df.sort_values(by=['Y','Z'], ascending=False)
df2
# Out:
#     V   W   X   Y   Z
# a  63  65  46  95  73
# b  68  43  92  92  62
# d  93  87  53  79  45
# c  77  72  62  57  87

# %%
df2.sort_index()
# Out:
#     V   W   X   Y   Z
# a  63  65  46  95  73
# b  68  43  92  92  62
# c  77  72  62  57  87
# d  93  87  53  79  45

# %% [markdown]
# ![Alt text](image-4.png)

# %%
print(titanic.sex.value_counts())
print(titanic.alive.value_counts())
# Out:
# male      577
# female    314
# Name: sex, dtype: int64
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
# 연속적인 값에 대해서 value_count()를 하는 것은 바람직하지 않음
titanic.age.value_counts().head()
# Out:
# 24.0    30
# 22.0    27
# 18.0    26
# 19.0    25
# 28.0    25
# Name: age, dtype: int64

# %% [markdown]
# - 행/열 합계

# %%
df
# Out:
#     V   W   X   Y   Z
# a  63  65  46  95  73
# b  68  43  92  92  62
# c  77  72  62  57  87
# d  93  87  53  79  45

# %%
# 행의 합계
df['행합계'] = df.sum(axis=1)
df
# Out:
#     V   W   X   Y   Z  행합계
# a  63  65  46  95  73  342
# b  68  43  92  92  62  357
# c  77  72  62  57  87  355
# d  93  87  53  79  45  357

# %%
# 행의 평균
df['행평균'] = df[list('VWXYZ')].mean(axis=1)
df
# Out:
#     V   W   X   Y   Z  행합계   행평균
# a  63  65  46  95  73  342  68.4
# b  68  43  92  92  62  357  71.4
# c  77  72  62  57  87  355  71.0
# d  93  87  53  79  45  357  71.4

# %%
# 행의 평균2
df['행평균2'] = df.iloc[:, :5].mean(axis=1)
df
# Out:
#     V   W   X   Y   Z  행합계   행평균  행평균2
# a  63  65  46  95  73  342  68.4  68.4
# b  68  43  92  92  62  357  71.4  71.4
# c  77  72  62  57  87  355  71.0  71.0
# d  93  87  53  79  45  357  71.4  71.4

# %%
# 행 추가하는 방법: 열 합계
df.loc['열합계', :] = df.sum(axis=0)
df
# Out:
#          V      W      X      Y      Z     행합계    행평균   행평균2
# a     63.0   65.0   46.0   95.0   73.0   342.0   68.4   68.4
# b     68.0   43.0   92.0   92.0   62.0   357.0   71.4   71.4
# c     77.0   72.0   62.0   57.0   87.0   355.0   71.0   71.0
# d     93.0   87.0   53.0   79.0   45.0   357.0   71.4   71.4
# 열합계  301.0  267.0  253.0  323.0  267.0  1411.0  282.2  282.2

# %% [markdown]
# ![Alt text](image-6.png)

# %%
#1. 타이타닉호 승핵의 평균 나이를 구하라.
titanic.age.mean().round(2)
# Out:
# 29.7

# %%
# 2. 타이타닉호 승객중 여성 승객의 평균 나이를 구하라.
tf = titanic[titanic.sex == 'female']       # filtering
tf.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False

# %%
titanic[titanic.sex == 'female'].age.mean().round(2)
# Out:
# 27.92

# %%
# 3. 타이타닉호 승객중 1등실 선실의 여성 승객의 쳥균 나이를 구하라.
tf1 = tf[tf.pclass == 1]
tf.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False

# %%
tf1.age.mean().round(2)
# Out:
# 34.61

# %%
titanic[(titanic.pclass == 1) & (titanic.sex == 'female')].age.mean().round(2)
# Out:
# 34.61

# %% [markdown]
# - apply 변환

# %%
np.random.seed(2023)
df = pd.DataFrame(np.random.randint(40, 101, size=(4, 5)),
                  index=list('abcd'), columns=list('VWXYZ'))
df
# Out:
#     V   W   X   Y   Z
# a  63  65  46  95  73
# b  68  43  92  92  62
# c  77  72  62  57  87
# d  93  87  53  79  45

# %%
# 각 열에서 최대값 - 최소값
df.apply(lambda x: x.max() - x.min())   # x는 각 column을 의미
# Out:
# V    30
# W    44
# X    46
# Y    38
# Z    42
# dtype: int64

# %%
# V 열의 제곱수
df.V.apply(lambda x: x * x)     # X는 V 열의 각 엘리먼트
# Out:
# a    3969
# b    4624
# c    5929
# d    8649
# Name: V, dtype: int64

# %%
# map(함수)
# series/DF
# series.apply(함수)
# DF.apply(함수)  => x 는 열
# DF.apply(함수, axis=1) => x는 행

# %%
# 각 행에서 최대값 - 최소값 한 결과 - axis =1 을 주면 됨
df.apply(lambda x: x.max() - x.min(), axis=1)   # x는 각 행을 의미
# Out:
# a    49
# b    49
# c    30
# d    48
# dtype: int64

# %%
# 다음과 같이 타이타닉호의 승객 중 나이 20살을 기준으로 성인(adult)과 미성년자(child)를 구별
titanic['adult/child'] = titanic.apply(lambda x: 'adult' if x.age >= 20 else 'child', axis=1)
titanic.tail()      # 행의 갯수만큼 나와야 하기 때문에 axis=1 이 되어야 함.
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone adult/child
# 886    man        True  NaN  Southampton    no   True       adult
# 887  woman       False    B  Southampton   yes   True       child
# 888  woman       False  NaN  Southampton    no  False       child
# 889    man        True    C    Cherbourg   yes   True       adult
# 890    man        True  NaN   Queenstown    no   True       adult

# %% [markdown]
# ![Alt text](image-7.png)

# %%
# 20살이 넘으면 성별을 그대로 사용한다. 
titanic['catagory1'] = titanic.apply(lambda x: x.sex if x.age >= 20 else 'child', axis=1)
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone adult/child catagory1
# 886    man        True  NaN  Southampton    no   True       adult      male
# 887  woman       False    B  Southampton   yes   True       child     child
# 888  woman       False  NaN  Southampton    no  False       child     child
# 889    man        True    C    Cherbourg   yes   True       adult      male
# 890    man        True  NaN   Queenstown    no   True       adult      male

# %%
data = {
    'text' : ['03.입출력.ipynb', '04.고급인덱싱.ipynb', '05.데이터조작.ipynb'],
    'price' : ['24,000', '36,000', '42,000']
}
df1 = pd.DataFrame(data)
df1
# Out:
#              text   price
# 0    03.입출력.ipynb  24,000
# 1  04.고급인덱싱.ipynb  36,000
# 2  05.데이터조작.ipynb  42,000

# %%
# 구둣점 제거 열 생성
df1['구둣점 제거'] =  df1.text.apply(lambda x: x.replace('.',''))
df1
# Out:
#              text   price        구둣점 제거
# 0    03.입출력.ipynb  24,000    03입출력ipynb
# 1  04.고급인덱싱.ipynb  36,000  04고급인덱싱ipynb
# 2  05.데이터조작.ipynb  42,000  05데이터조작ipynb

# %%
# 한글 텍스트 열 생성
# df1['한글 텍스트'] = df1.text.apply(lambda x: x.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]',' ')) - 구 판다스
# [^ ] 아니라는 뜻 
df1['한글 텍스트'] = df1.text.str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]', '', regex=True)
df1
# Out:
#              text   price        구둣점 제거 한글 텍스트
# 0    03.입출력.ipynb  24,000    03입출력ipynb    입출력
# 1  04.고급인덱싱.ipynb  36,000  04고급인덱싱ipynb  고급인덱싱
# 2  05.데이터조작.ipynb  42,000  05데이터조작ipynb  데이터조작

# %%
# price 문자열을 정수로 변환하여 가격 열 생성
df1['가격'] = df1.price.apply(lambda x: int(x.replace(',', '')))
df1
# Out:
#              text   price        구둣점 제거 한글 텍스트     가격
# 0    03.입출력.ipynb  24,000    03입출력ipynb    입출력  24000
# 1  04.고급인덱싱.ipynb  36,000  04고급인덱싱ipynb  고급인덱싱  36000
# 2  05.데이터조작.ipynb  42,000  05데이터조작ipynb  데이터조작  42000

# %%
x = '12,000'
int(x.replace(',',''))      # int(x) 하면 , 때문에 출력 안됨
# Out:
# 12000

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# - 결측치 처리

# %%
dt = sns.load_dataset('titanic')
dt.shape
# Out:
# (891, 15)

# %%
# 데이터프레임에 결측치가 있는지 확인
dt.isna().sum().sum()
# Out:
# 869

# %%
# 어느 열에 결측치가 있는지 확인 
dt.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# 너무 믾으면 삭제
dt.drop(columns=['deck'], inplace=True)       #더 삭제 하고 싶으면 , 로 더 적으면 됨
dt.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True

# %%
# 숫자 데이터 대체 - 평균 또는 중앙값으로 대체
dt.age.fillna(dt.age.mean().round(2), inplace=True)
dt.tail(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 888         0       3  female  29.7      1      2  23.45        S  Third
# 889         1       1    male  26.0      0      0  30.00        C  First
# 890         0       3    male  32.0      0      0   7.75        Q  Third
#
#        who  adult_male  embark_town alive  alone
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True

# %%
# 카테고리 데이터 대체 - 최빈값으로 대체 
dt.embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
dt.embarked.fillna('S', inplace=True)
dt.embarked.value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
# 중복 데이터 열인: embark_town, class, who, adult_male, alive, alone은 제거
dt.drop(columns='embark_town,class,who,adult_male,alive,alone'.split(','), inplace=True)
dt.head() # 이러한 과정을 셀렉션이라고 함.
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# - 타입 변환:astype()

# %%
df3 = pd.DataFrame({
    'A': [1, 3, 4, 3, 4],
    'B': [2, 3, 1, 2, 3],
    'C': [1, 5, 2, 4, 4]
})
df3.apply(pd.value_counts)
# Out:
#      A    B    C
# 1  1.0  1.0  1.0
# 2  NaN  2.0  1.0
# 3  2.0  2.0  NaN
# 4  2.0  NaN  2.0
# 5  NaN  NaN  1.0

# %%
# 결측치를 0으로 바꾸고, 전체를 정수형으로 변환
df3 = df3.fillna(0).astype(int) # (0.0)으로 해도 됨
df3
# Out:
#    A  B  C
# 0  1  2  1
# 1  3  3  5
# 2  4  1  2
# 3  3  2  4
# 4  4  3  4

# %%
df5 = pd.DataFrame({
    'price1':['1200','2400','3200'],
    'price2':['1,200','2,400','3,200'],
})
df5
# Out:
#   price1 price2
# 0   1200  1,200
# 1   2400  2,400
# 2   3200  3,200

# %%
type(df5.price1[0]), type(df5.price2[2])
# Out:
# (str, str)

# %%
# price1을 정수형으로 변환시킨 int1 열 생성
df5['int1'] = df5.price1.astype(int)
df5
# Out:
#   price1 price2  int1
# 0   1200  1,200  1200
# 1   2400  2,400  2400
# 2   3200  3,200  3200

# %%
type(df5.price1[0]), type(df5.int1[0])
# Out:
# (str, numpy.int32)

# %%
# price2를 정수형으로 변환시킨 int2 열 생성
df5['int2'] = df5.price2.apply(lambda x: int(x.replace(',','')))
df5
# Out:
#   price1 price2  int1  int2
# 0   1200  1,200  1200  1200
# 1   2400  2,400  2400  2400
# 2   3200  3,200  3200  3200

# %%
type(df5.price2[0]), type(df5.int2[0])
# Out:
# (str, numpy.int64)

# %%
df5['int2'] = df5.price2.str.replace(',', '').astype(int)
df5
# Out:
#   price1 price2  int1  int2
# 0   1200  1,200  1200  1200
# 1   2400  2,400  2400  2400
# 2   3200  3,200  3200  3200

# %%
type(df5.price2[0]), type(df5.int2[0])
# Out:
# (str, numpy.int32)

# %% [markdown]
# ![Alt text](image-8.png)

# %%
titanic.tail(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 888         0       3  female   NaN      1      2  23.45        S  Third
# 889         1       1    male  26.0      0      0  30.00        C  First
# 890         0       3    male  32.0      0      0   7.75        Q  Third
#
#        who  adult_male deck  embark_town alive  alone adult/child catagory1
# 888  woman       False  NaN  Southampton    no  False       child     child
# 889    man        True    C    Cherbourg   yes   True       adult      male
# 890    man        True  NaN   Queenstown    no   True       adult      male

# %%
titanic['category2'] = titanic.sex+titanic.age.astype(str)  # 람다식으로 바꿔야함. 
titanic.tail(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 888         0       3  female   NaN      1      2  23.45        S  Third
# 889         1       1    male  26.0      0      0  30.00        C  First
# 890         0       3    male  32.0      0      0   7.75        Q  Third
#
#        who  adult_male deck  embark_town alive  alone adult/child catagory1  \
# 888  woman       False  NaN  Southampton    no  False       child     child
# 889    man        True    C    Cherbourg   yes   True       adult      male
# 890    man        True  NaN   Queenstown    no   True       adult      male
#
#      category2
# 888  femalenan
# 889   male26.0
# 890   male32.0

# %%
titanic['category2'] = \
    titanic.apply(lambda x: x.sex + str(x.age).split('.')[0] if x.age >= 0 else x.sex, axis=1)
titanic.tail(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 888         0       3  female   NaN      1      2  23.45        S  Third
# 889         1       1    male  26.0      0      0  30.00        C  First
# 890         0       3    male  32.0      0      0   7.75        Q  Third
#
#        who  adult_male deck  embark_town alive  alone adult/child catagory1  \
# 888  woman       False  NaN  Southampton    no  False       child     child
# 889    man        True    C    Cherbourg   yes   True       adult      male
# 890    man        True  NaN   Queenstown    no   True       adult      male
#
#     category2
# 888    female
# 889    male26
# 890    male32

# %% [markdown]
# - 실수 값을 카테고리 값으로 변환

# %%
ages = [0, 2, 10, 21, 23, 37, 31, 61, 20, 41, 32, 101]

# %%
bins = [1, 20, 30, 50, 70, 100]                             # 1 < 미성년자 <= 20
labels = ["미성년자", "청년", "중년", "장년", "노년"]

# %%
cats = pd.cut(ages, bins, labels=labels)
cats
# Out:
# [NaN, '미성년자', '미성년자', '청년', '청년', ..., '장년', '미성년자', '중년', '중년', NaN]
# Length: 12
# Categories (5, object): ['미성년자' < '청년' < '중년' < '장년' < '노년']

# %%
pd.qcut(ages, 4, labels=['Q1', 'Q2', 'Q3', 'Q4'])
# Out:
# ['Q1', 'Q1', 'Q1', 'Q2', 'Q2', ..., 'Q4', 'Q2', 'Q4', 'Q3', 'Q4']
# Length: 12
# Categories (4, object): ['Q1' < 'Q2' < 'Q3' < 'Q4']

# %% [markdown]
# - 연습문제 4.47
#
# ![Alt text](image-9.png)

# %%
titanic_cats = pd.cut(titanic.age, bins, labels=labels)
titanic_cats.value_counts()
# Out:
# 중년      241
# 청년      230
# 미성년자    165
# 장년       59
# 노년        5
# Name: age, dtype: int64

# %%
# 승객 비율 구하기 
titanic_cats.value_counts() / titanic_cats.value_counts().sum() * 100
# Out:
# 중년      34.428571
# 청년      32.857143
# 미성년자    23.571429
# 장년       8.428571
# 노년       0.714286
# Name: age, dtype: float64

# %% [markdown]
# ![Alt text](image-10.png)

# %%
bins = [0,19,30,50,70,100]
titanic['age_group'] = pd.cut(titanic.age, bins, labels=labels)
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone adult/child catagory1  \
# 886    man        True  NaN  Southampton    no   True       adult      male
# 887  woman       False    B  Southampton   yes   True       child     child
# 888  woman       False  NaN  Southampton    no  False       child     child
# 889    man        True    C    Cherbourg   yes   True       adult      male
# 890    man        True  NaN   Queenstown    no   True       adult      male
#
#     category2 age_group
# 886    male27        청년
# 887  female19      미성년자
# 888    female       NaN
# 889    male26        청년
# 890    male32        중년

# %%
titanic['category3'] = \

# %%
# age의 결측치를 평균으로 대체
titanic.age.fillna(titanic.age.mean().round(2),inplace=True)
titanic['age_group'] = pd.cut(titanic.age, bins, labels=labels)
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  29.7      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone adult/child catagory1  \
# 886    man        True  NaN  Southampton    no   True       adult      male
# 887  woman       False    B  Southampton   yes   True       child     child
# 888  woman       False  NaN  Southampton    no  False       child     child
# 889    man        True    C    Cherbourg   yes   True       adult      male
# 890    man        True  NaN   Queenstown    no   True       adult      male
#
#     category2 age_group
# 886    male27        청년
# 887  female19      미성년자
# 888    female        청년
# 889    male26        청년
# 890    male32        중년

# %%
titanic['성별'] = titanic.sex.apply(lambda x: '남성' if x == 'male' else '여성')
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  29.7      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone adult/child catagory1  \
# 886    man        True  NaN  Southampton    no   True       adult      male
# 887  woman       False    B  Southampton   yes   True       child     child
# 888  woman       False  NaN  Southampton    no  False       child     child
# 889    man        True    C    Cherbourg   yes   True       adult      male
# 890    man        True  NaN   Queenstown    no   True       adult      male
#
#     category2 age_group  성별
# 886    male27        청년  남성
# 887  female19      미성년자  여성
# 888    female        청년  여성
# 889    male26        청년  남성
# 890    male32        중년  남성

# %%
titanic['category3'] = titanic.apply(
    lambda x: x.age_group + x.성별 if x.age >= 20 else '미성년자', axis=1)
titanic.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  29.7      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  ...  deck  embark_town alive  alone  adult/child catagory1  \
# 881    man  ...   NaN  Southampton    no   True        adult      male
# 882  woman  ...   NaN  Southampton    no   True        adult    female
# 883    man  ...   NaN  Southampton    no   True        adult      male
# 884    man  ...   NaN  Southampton    no   True        adult      male
# 885  woman  ...   NaN   Queenstown    no  False        adult    female
# 886    man  ...   NaN  Southampton    no   True        adult      male
# 887  woman  ...     B  Southampton   yes   True        child     child
# 888  woman  ...   NaN  Southampton    no  False        child     child
# 889    man  ...     C    Cherbourg   yes   True        adult      male
# 890    man  ...   NaN   Queenstown    no   True        adult      male
#
#     category2 age_group  성별 category3
# 881    male33        중년  남성      중년남성
# 882  female22        청년  여성      청년여성
# 883    male28        청년  남성      청년남성
# 884    male25        청년  남성      청년남성
# 885  female39        중년  여성      중년여성
# 886    male27        청년  남성      청년남성
# 887  female19      미성년자  여성      미성년자
# 888    female        청년  여성      청년여성
# 889    male26        청년  남성      청년남성
# 890    male32        중년  남성      중년남성
#
# [10 rows x 21 columns]
