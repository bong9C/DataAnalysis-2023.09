# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.normal(1, 2, 200)      # 정규분포
Y = np.random.uniform(-2, 4, 200)

# %%
plt.scatter(X,Y);
plt.savefig('static/img/scatter.png')
