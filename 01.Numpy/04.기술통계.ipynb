# %% [markdown]
# ### 1.4 기술 통계

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
x = np.array([18,   5,  10,  23,  19,  -8,  10,   0,   0,   5,   2,  15,   8,
              2,   5,   4,  15,  -1,   4,  -7, -24,   7,   9,  -6,  23, -13])

# %% [markdown]
# - 테이터의 갯수

# %%
x.size, len(x)
# Out:
# (26, 26)

# %% [markdown]
# - 표본 평균

# %%
np.mean(x), x.mean()
# Out:
# (4.8076923076923075, 4.8076923076923075)

# %%
np.sum(x) / x.size
# Out:
# 4.8076923076923075

# %% [markdown]
# - 표본(Sample) 분산(Variance)

# %%
np.var(x), x.var()
# Out:
# (115.23224852071006, 115.23224852071006)

# %%
# 비편향 분산, 표본 분산은 N - 1로 나누어 준다.
np.var(x, ddof=1)
# 모집단 : np.var(x)
# Out:
# 119.84153846153846

# %% [markdown]
# - 표본 표준편차(Standard Devation)

# %%
np.std(x), x.std(), np.sqrt(np.var(x))
# Out:
# (10.734628476137871, 10.734628476137871, 10.734628476137871)

# %%
# 표본집단의 표준편차(비편향 표준편차)
np.stx(x,ddof=1), x.std(ddof=1)

# %% [markdown]
# - 최대값, 최소값

# %%
np.max(x), x.max(), np.min(x), x.min()
# Out:
# (23, 23, -24, -24)

# %% [markdown]
# - 중앙값

# %%
np.sort(x)
# Out:
# array([-24, -13,  -8,  -7,  -6,  -1,   0,   0,   2,   2,   4,   4,   5,
#          5,   5,   7,   8,   9,  10,  10,  15,  15,  18,  19,  23,  23])

# %%
np.median(x)
# Out:
# 5.0

# %% [markdown]
# - 사분위수(Quartile) : 정규분포를 약식으로 표시해서 볼 수 있는 방법

# %%
# Box plot
import matplotlib.pyplot as plt
plt.boxplot(x)
plt.show()

# %%
np.percentile(x, 0), np.percentile(x, 25), np.percentile(x, 50), np.percentile(x, 75), np.percentile(x, 100)
# Out:
# (-24.0, 0.0, 5.0, 10.0, 23.0)

# %%
# 최소값인 -24.0은 그림에서 동그라미로 표시되고, 동그라미로 표시된 데이터는
# 이상치(Outlier)라 함
