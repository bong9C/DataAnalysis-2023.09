# %% [markdown]
# ## 서울시 CCTV 인구 시각화

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('../02.Pandas/data/서울시 구별 CCTV 인구 현황.csv', index_col='구별')
df.head()
# Out:
#      CCTV댓수  최근증가율     인구수     내국인    외국인    고령자  외국인 비율  고령자 비율
# 구별
# 종로구    1835  28.77  152212  141060  11152  28265    7.33   18.57
# 중구     2584  34.87  131390  120963  10427  25353    7.94   19.30
# 용산구    2970  50.81  232482  217756  14726  39478    6.33   16.98
# 성동구    4040  26.83  287240  280240   7000  48238    2.44   16.79
# 광진구    3480  34.51  350925  336801  14124  54854    4.02   15.63

# %% [markdown]
# 1. 자치구별 CCTV 설치 댓수

# %%
df.CCTV댓수.plot(kind= 'barh')
plt.title('서울시 구별 CCTV 설치 댓수');

# %%
# CCTV 댓수로 정렬하고, plt.bath() 로 그리기
sc = df['CCTV댓수'].sort_values()
plt.barh(sc.index, sc.values)
plt.title('서울시 구별 CCTV 설치 갯수 정렬 완료');

# %%
# Seabron으로 그리기
sns.barplot(data=df, y=df.index, x='CCTV댓수') 
plt.title('서울시 구별 CCTV 설치 댓수');

# %%
scr = df['CCTV댓수'].sort_values(ascending=False)
sns.barplot(y=scr.index, x=scr.values)
plt.title('서울시 구별 CCTV 설치 댓수');

# %% [markdown]
# ##### 2. 구별 인당 CCTV 댓수 그리기 - plt.barh() 로 그리기

# %%
df['인당 CCTV댓수'] = df['CCTV댓수'] / df['인구수']
df
# Out:
#       CCTV댓수  최근증가율     인구수     내국인    외국인     고령자  외국인 비율  고령자 비율  인당 CCTV댓수
# 구별
# 종로구     1835  28.77  152212  141060  11152   28265    7.33   18.57   0.012056
# 중구      2584  34.87  131390  120963  10427   25353    7.94   19.30   0.019667
# 용산구     2970  50.81  232482  217756  14726   39478    6.33   16.98   0.012775
# 성동구     4040  26.83  287240  280240   7000   48238    2.44   16.79   0.014065
# 광진구     3480  34.51  350925  336801  14124   54854    4.02   15.63   0.009917
# 동대문구    2750  28.18  354884  337574  17310   65154    4.88   18.36   0.007749
# 중랑구     4193  42.38  389928  385003   4925   76116    1.26   19.52   0.010753
# 성북구     4853  20.56  441855  430100  11755   78427    2.66   17.75   0.010983
# 강북구     3321  50.11  296934  292762   4172   67056    1.41   22.58   0.011184
# 도봉구     2126  64.06  312858  310509   2349   68114    0.75   21.77   0.006795
# 노원구     2608  28.60  506989  502515   4474   93279    0.88   18.40   0.005144
# ...

# %%
#이렇게도 할 수 있음 
df['CCTV댓수'] / df['인구수'].sort_values()   #sort_values() 를 하면 바로 인당 CCTV 댓수만 나옴
# Out:
# 구별
# 강남구     0.013467
# 강동구     0.006875
# 강북구     0.011184
# 강서구     0.005773
# 관악구     0.010423
# 광진구     0.009917
# 구로구     0.011132
# 금천구     0.010929
# 노원구     0.005144
# 도봉구     0.006795
# 동대문구    0.007749
# 동작구     0.006824
# 마포구     0.006979
# 서대문구    0.010700
# 서초구     0.012213
# 성동구     0.014065
# 성북구     0.010983
# 송파구     0.004752
# 양천구     0.008794
# 영등포구    0.011639
# 용산구     0.012775
# 은평구     0.009926
# 종로구     0.012056
# 중구      0.019667
# 중랑구     0.010753
# dtype: float64

# %%
sc = df['인당 CCTV댓수'].sort_values()
plt.barh(sc.index, sc.values)
plt.title('서울시 구별 인당 CCTV 설치 갯수 정렬 완료');

# %%
# 이렇게 바로 할 수도 있음 
s = (df['CCTV댓수'] / df['인구수']).sort_values()   #sort_values() 를 하면 바로 인당 CCTV 댓수만 나옴
plt.barh(s.index, s.values)
plt.title('구별 인당 CCTV 댓수');

# %% [markdown]
# #### 3. 구별 외국인당 CCTV 댓수 - Seaborn

# %%
scr = (df['CCTV댓수'] / df['외국인']).sort_values(ascending=False)   #sort_values() 를 하면 바로 인당 CCTV 댓수만 나옴
sns.barplot(y=scr.index, x=scr.values)
plt.barh(s.index, s.values)
plt.title('구별 인당 CCTV 댓수');

# %% [markdown]
# #### 4.인구수와 CCTV 갯수 분석
# - 산점도

# %%
plt.figure(figsize=(6,6))
plt.scatter(df['인구수'],df['CCTV댓수'])
plt.grid(), plt.xlabel('인구수'), plt.ylabel('CCTV 댓수')
plt.show()

# %% [markdown]
# - 회귀선

# %%
fp1 = np.polyfit(df['인구수'], df['CCTV댓수'], 1)
fp1           # [기울기, 절편]
# Out:
# array([4.52184187e-03, 1.89611186e+03])

# %%
fx = np.array([100000, 700000])
fy = fx * fp1[0] + fp1[1]                    # fp1[0] => 기울기, fp1[1]  => 절편
fy
# Out:
# array([2348.29605146, 5061.40117469])

# %%
f1 = np.poly1d(fp1)                 # X값을 주면 Y값을 구해주는 함수
fy = f1(fx)                         # 위에 값이랑 똑같음!
fy
# Out:
# array([2348.29605146, 5061.40117469])

# %%
plt.figure(figsize=(6,6))
plt.scatter(df['인구수'],df['CCTV댓수'])
plt.plot(fx, fy, 'g--', lw=3)
plt.title('인구수와 CCTV 의 관계', fontsize=3)
plt.grid(), plt.xlabel('인구수'), plt.ylabel('CCTV 댓수')
plt.show()

# %% [markdown]
# - 오차의 절대값

# %%
df['오차'] = abs(df['CCTV댓수'] - f1(df['인구수'])).round(1)
df.head(3)
# Out:
#      CCTV댓수  최근증가율     인구수     내국인    외국인    고령자  외국인 비율  고령자 비율  인당 CCTV댓수  \
# 구별
# 종로구    1835  28.77  152212  141060  11152  28265    7.33   18.57   0.012056
# 중구     2584  34.87  131390  120963  10427  25353    7.94   19.30   0.019667
# 용산구    2970  50.81  232482  217756  14726  39478    6.33   16.98   0.012775
#
#         오차
# 구별
# 종로구  749.4
# 중구    93.8
# 용산구   22.6

# %%
# 오차의 내림차순으로 정렬
df.sort_values(by='오차', ascending=False).head()
# Out:
#      CCTV댓수  최근증가율     인구수     내국인   외국인     고령자  외국인 비율  고령자 비율  인당 CCTV댓수  \
# 구별
# 강남구    7243  26.30  537817  532798  5019   83097    0.93   15.45   0.013467
# 송파구    3154  25.97  663704  658006  5698  105161    0.86   15.84   0.004752
# 노원구    2608  28.60  506989  502515  4474   93279    0.88   18.40   0.005144
# 서초구    4995  37.32  408979  404831  4148   63328    1.01   15.48   0.012213
# 도봉구    2126  64.06  312858  310509  2349   68114    0.75   21.77   0.006795
#
#          오차
# 구별
# 강남구  2915.0
# 송파구  1743.3
# 노원구  1580.6
# 서초구  1249.5
# 도봉구  1184.8

# %%
# 정렬된 데이터에서 Top 10만 골라내기
df_sort = df.sort_values(by='오차', ascending=False).head(10)
df_sort
# Out:
#      CCTV댓수  최근증가율     인구수     내국인    외국인     고령자  외국인 비율  고령자 비율  인당 CCTV댓수  \
# 구별
# 강남구    7243  26.30  537817  532798   5019   83097    0.93   15.45   0.013467
# 송파구    3154  25.97  663704  658006   5698  105161    0.86   15.84   0.004752
# 노원구    2608  28.60  506989  502515   4474   93279    0.88   18.40   0.005144
# 서초구    4995  37.32  408979  404831   4148   63328    1.01   15.48   0.012213
# 도봉구    2126  64.06  312858  310509   2349   68114    0.75   21.77   0.006795
# 강서구    3312  42.27  573711  568287   5424   98659    0.95   17.20   0.005773
# 관악구    5239  20.77  502628  487815  14813   83420    2.95   16.60   0.010423
# 동작구    2664  31.38  390377  380201  10176   68766    2.61   17.62   0.006824
# 마포구    2628  22.53  376542  365570  10972   56582    2.91   15.03   0.006979
# 성북구    4853  20.56  441855  430100  11755   78427    2.66   17.75   0.010983
#
#          오차
# 구별
# 강남구  2915.0
# 송파구  1743.3
# 노원구  1580.6
# 서초구  1249.5
# 도봉구  1184.8
# 강서구  1178.3
# 관악구  1070.1
# ...

# %% [markdown]
# - 최종 그래프

# %%
plt.figure(figsize=(12,9))
plt.scatter(df['인구수'],df['CCTV댓수'], c=df['오차'])
plt.plot(fx, fy, 'g--', lw=3)

for i in range(10):
    if i == 8:
        continue
    plt.text(df_sort['인구수'][i]+8000, df_sort['CCTV댓수'][i]-50, 
         df_sort.index[i], fontsize=12)      # x좌표 ,[0]대신 ['강남구']라고 해도 됨, y좌표 ,[0]대신 ['7243']라고 해도 됨
plt.text(df_sort['인구수'][8]-5000, df_sort['CCTV댓수'][8]-200, 
        df_sort.index[8], fontsize=12)

plt.title('인구수와 CCTV 의 관계', fontsize=15)
plt.grid(), plt.xlabel('인구수'), plt.ylabel('CCTV 댓수')
plt.colorbar()
plt.show()
