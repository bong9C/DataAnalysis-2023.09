# %% [markdown]
# ### 여러개 그래프

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 1. subplot

# %%
from PIL import Image
img1 = Image.open('data/야옹이.jpg')
img2 = Image.open('data/삼각함수.png')

# %%
plt.figure(figsize=(10, 4))
plt.subplot(121)
plt.imshow(img1), plt.title('야옹이')
plt.subplot(1, 2, 2)
plt.imshow(img2), plt.title('삼각함수')
plt.show()

# %%
# Iris 각 품종별 sepal_length VS sepal_width
import seaborn as sns
iris = sns.load_dataset('iris')
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 3, 1)
plt.scatter(iris[iris.species == 'setosa'].sepal_length,iris[iris.species == 'setosa'].sepal_width )
plt.title('setosa')
plt.subplot(1, 3, 2)
plt.scatter(iris[iris.species == 'versicolor'].sepal_length,iris[iris.species == 'versicolor'].sepal_width )
plt.title('versicolor')
plt.subplot(1, 3, 3)
plt.scatter(iris[iris.species == 'virginica'].sepal_length,iris[iris.species == 'virginica'].sepal_width )
plt.title('virginica')
# Out:
# Text(0.5, 1.0, 'virginica')

# %%
# enumerate 반복문 사용해서 표현하기. 

plt.figure(figsize=(12, 4))
for i, species in enumerate(iris.species.unique()):
    plt.subplot(1, 3, i + 1)
    plt.scatter(iris[iris.species == species].sepal_length,iris[iris.species == species].sepal_width )
    plt.title(species), plt.xlabel('sepal length'), plt.ylabel('sepal width')
plt.show()

# %% [markdown]
# - Anscombe's Quartet

# %%
ans = sns.load_dataset('anscombe')
ans.head(3)
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58

# %%
ans.tail(3)
# Out:
#    dataset    x     y
# 41      IV  8.0  5.56
# 42      IV  8.0  7.91
# 43      IV  8.0  6.89

# %%
ans.groupby('dataset')['x'].agg(['mean','std'])
# Out:
#          mean       std
# dataset
# I         9.0  3.316625
# II        9.0  3.316625
# III       9.0  3.316625
# IV        9.0  3.316625

# %%
ans.pivot_table('y', 'dataset', aggfunc=['mean', 'std'])
# Out:
#              mean       std
#                 y         y
# dataset
# I        7.500909  2.031568
# II       7.500909  2.031657
# III      7.500000  2.030424
# IV       7.500909  2.030579

# %%
# 회귀식: y = 0.5 * x + 3

# %%
plt.figure(figsize=(12, 4))

for i, roman in enumerate(ans.dataset.unique()):        # ['I','II','III','IV']
    ds = ans[ans.dataset == roman]
    plt.subplot(2, 2, i+1)
    plt.scatter(ds.x, ds.y, marker='0')
    plt.plot([2,20], [4, 13], 'r', lw=-2)
    plt.xlim(2, 20), plt.ylim(2, 14)
    plt.title(f'Dataset {roman}')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\human\anaconda3\Lib\site-packages\matplotlib\markers.py:359, in MarkerStyle._set_marker(self, marker)
#     358 try:
# --> 359     Path(marker)
#     360     self._marker_function = self._set_vertices
#
# File c:\Users\human\anaconda3\Lib\site-packages\matplotlib\path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None:
#
# File c:\Users\human\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:168, in check_shape(_shape, **kwargs)
#     166     text_shape += ","
# --> 168 raise ValueError(
#     169     f"{k!r} must be {len(target_shape)}D "
#     170     f"with shape ({text_shape}). "
#     171     f"Your input has shape {v.shape}."
#     172 )
#
# ValueError: 'vertices' must be 2D with shape (M, 2). Your input has shape ().
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# d:\WorkSpace\03.시각화\05.MuitiPlot.ipynb 셀 15 line 6
#       <a href='vscode-notebook-cell:/d%3A/WorkSpace/03.%EC%8B%9C%EA%B0%81%ED%99%94/05.MuitiPlot.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> ds = ans[ans.dataset == roman]
#       <a href='vscode-notebook-cell:/d%3A/WorkSpace/03.%EC%8B%9C%EA%B0%81%ED%99%94/05.MuitiPlot.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> plt.subplot(2, 2, i+1)
# ----> <a href='vscode-notebook-cell:/d%3A/WorkSpace/03.%EC%8B%9C%EA%B0%81%ED%99%94/05.MuitiPlot.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> plt.scatter(ds.x, ds.y, marker='0')
#       <a href='vscode-notebook-cell:/d%3A/WorkSpace/03.%EC%8B%9C%EA%B0%81%ED%99%94/05.MuitiPlot.ipynb#X20sZmlsZQ%3D%3D?line=6'>7</a> plt.plot([2,20], [4, 13], 'r', lw=-2)
#       <a href='vscode-notebook-cell:/d%3A/WorkSpace/03.%EC%8B%9C%EA%B0%81%ED%99%94/05.MuitiPlot.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> plt.xlim(2, 20), plt.ylim(2, 14)
#
# File c:\Users\human\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2865         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2866         **({"data": data} if data is not None else {}), **kwargs)
#    2867     sci(__ret)
#    2868     return __ret
#
# File c:\Users\human\anaconda3\Lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File c:\Users\human\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:4629, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4627     marker_obj = marker
#    4628 else:
# -> 4629     marker_obj = mmarkers.MarkerStyle(marker)
#    4631 path = marker_obj.get_path().transformed(
#    4632     marker_obj.get_transform())
#    4633 if not marker_obj.is_filled():
#
# File c:\Users\human\anaconda3\Lib\site-packages\matplotlib\markers.py:272, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     267     marker = ""
#     268     _api.warn_deprecated(
#     269         "3.6", message="MarkerStyle(None) is deprecated since "
#     270         "%(since)s; support will be removed %(removal)s.  Use "
#     271         "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272 self._set_marker(marker)
#
# File c:\Users\human\anaconda3\Lib\site-packages\matplotlib\markers.py:362, in MarkerStyle._set_marker(self, marker)
#     360         self._marker_function = self._set_vertices
#     361     except ValueError as err:
# --> 362         raise ValueError('Unrecognized marker style {!r}'
#     363                          .format(marker)) from err
#     365 if not isinstance(marker, MarkerStyle):
#     366     self._marker = marker
#
# ValueError: Unrecognized marker style '0'

# %% [markdown]
# ### 2.subplots

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,8), sharex=True, sharey=T)
for i, roman in enumerate(ans.dataset.unique()):        # ['I','II','III','IV']
    ds = ans[ans.dataset == roman]
    ax = axes[i // 2, i % 2]                   # 행, 열 인덱스 
    ax.scatter(ds.x, ds.y, marker='0')
    ax.plot([2,20], [4, 13], 'r', lw=-2)       # 회귀식: ㅛ = 0.5 *  X + 3
    ax.set_xlim(2, 20), plt.ylim(2, 14)
    ax.set_title(f'Dataset {roman}')
fig.suptitle("Anscombe's Quartet", fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\WorkSpace\03.시각화\05.MuitiPlot.ipynb 셀 17 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/WorkSpace/03.%EC%8B%9C%EA%B0%81%ED%99%94/05.MuitiPlot.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> fig, axes = plt.subplots(2, 2, figsize=(10,8), sharex=True, sharey=T)
#       <a href='vscode-notebook-cell:/d%3A/WorkSpace/03.%EC%8B%9C%EA%B0%81%ED%99%94/05.MuitiPlot.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> for i, roman in enumerate(ans.dataset.unique()):        # ['I','II','III','IV']
#       <a href='vscode-notebook-cell:/d%3A/WorkSpace/03.%EC%8B%9C%EA%B0%81%ED%99%94/05.MuitiPlot.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     ds = ans[ans.dataset == roman]
#
# NameError: name 'plt' is not defined

# %% [markdown]
# fig, axes = plt.subplots(2, 2, figsize)
