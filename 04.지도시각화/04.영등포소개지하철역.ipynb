# %% [markdown]
# ### 영등포구 소재 지하철역

# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('data/영등포소재 지하철역2.csv')
df
# Out:
#        이름                             주소         위도          경도
# 0    영등포역  서울특별시 영등포구 경인로 지하843 (영등포동3가)  37.516463  126.906659
# 1    신도림역       서울특별시 구로구 경인로 625 (신도림동)  37.507084  126.884719
# 2     당산역     서울특별시 영등포구 당산로 229 (당산동6가)  37.534957  126.902731
# 3    여의도역   서울특별시 영등포구 여의나루로 지하40 (여의도동)  37.521842  126.924485
# 4  영등포구청역   서울특별시 영등포구 당산로 지하121 (당산동3가)  37.525700  126.896627

# %%
map = folium.Map(location=[df.위도.mean(),df.경도.mean()], zoom_start=14) #Center position
for i in df.index:
    folium.Marker(
    location=[df.위도[i], df.경도[i]],
    tooltip=df.이름[i],
    popup=folium.Popup(df.주소[i], max_width=200)
    ).add_to(map)

title_html = '<h3 align="center" style="font=size:20px">영등포소재 주요 지하철역</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_575ef61819185dd96403d9210d728488 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font=size:20px&quot;&gt;영등포소재 주요 지하철역&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_575ef61819185dd96403d9210d728488&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_575ef61819185dd96403d9210d728488 = L.map(
#                 &quot;map_575ef61819185dd96403d9210d728488&quot;,
#                 {
#                     center: [37.52120913312664, 126.9030439466804],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28e7f625722818959473ce7752b9662b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_575ef61819185dd96403d9210d728488);
#
#
#             var marker_32c7d63c77970aec23fa1abf5a77e1b6 = L.marker(
#                 [37.5164625580995, 126.906658750671],
#                 {}
#             ).addTo(map_575ef61819185dd96403d9210d728488);
#
#
#         var popup_4babd6e7f38feef3810e9024a778af75 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_5ff0d0046e4e6c86631fa3908ce2b489 = $(`&lt;div id=&quot;html_5ff0d0046e4e6c86631fa3908ce2b489&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 경인로 지하843 (영등포동3가)&lt;/div&gt;`)[0];
#                 popup_4babd6e7f38feef3810e9024a778af75.setContent(html_5ff0d0046e4e6c86631fa3908ce2b489);
#
#
#
#         marker_32c7d63c77970aec23fa1abf5a77e1b6.bindPopup(popup_4babd6e7f38feef3810e9024a778af75)
#         ;
#
#
#
#
#             marker_32c7d63c77970aec23fa1abf5a77e1b6.bindTooltip(
#                 `&lt;div&gt;
#                      영등포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_51acde10c7ccd30adb2d8adcad598b62 = L.marker(
#                 [37.5070842748567, 126.884718686628],
#                 {}
#             ).addTo(map_575ef61819185dd96403d9210d728488);
#
#
#         var popup_4a1340dd8124d0fe401f0078fe226a7f = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_35e00647f54b51120d9a8268abb302d0 = $(`&lt;div id=&quot;html_35e00647f54b51120d9a8268abb302d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 구로구 경인로 625 (신도림동)&lt;/div&gt;`)[0];
#                 popup_4a1340dd8124d0fe401f0078fe226a7f.setContent(html_35e00647f54b51120d9a8268abb302d0);
#
#
#
#         marker_51acde10c7ccd30adb2d8adcad598b62.bindPopup(popup_4a1340dd8124d0fe401f0078fe226a7f)
#         ;
#
#
#
#
#             marker_51acde10c7ccd30adb2d8adcad598b62.bindTooltip(
#                 `&lt;div&gt;
#                      신도림역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b44d8add3786eaa537ef8cfd6ce7c029 = L.marker(
#                 [37.534956866618, 126.90273071003],
#                 {}
#             ).addTo(map_575ef61819185dd96403d9210d728488);
#
#
#         var popup_fcdbd5b0876c5ec6fb094b67f92dbcd7 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_eb465edc1f651d65937c9a0b7223297f = $(`&lt;div id=&quot;html_eb465edc1f651d65937c9a0b7223297f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 당산로 229 (당산동6가)&lt;/div&gt;`)[0];
#                 popup_fcdbd5b0876c5ec6fb094b67f92dbcd7.setContent(html_eb465edc1f651d65937c9a0b7223297f);
#
#
#
#         marker_b44d8add3786eaa537ef8cfd6ce7c029.bindPopup(popup_fcdbd5b0876c5ec6fb094b67f92dbcd7)
#         ;
#
#
#
#
#             marker_b44d8add3786eaa537ef8cfd6ce7c029.bindTooltip(
#                 `&lt;div&gt;
#                      당산역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_744e80dcfce17b36ff3006ae36301480 = L.marker(
#                 [37.5218423045786, 126.924484687694],
#                 {}
#             ).addTo(map_575ef61819185dd96403d9210d728488);
#
#
#         var popup_f34d389b466c4a87ae491744bcfd0b77 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_61c27f7b0250de7f8f7216232e68ad4c = $(`&lt;div id=&quot;html_61c27f7b0250de7f8f7216232e68ad4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 여의나루로 지하40 (여의도동)&lt;/div&gt;`)[0];
#                 popup_f34d389b466c4a87ae491744bcfd0b77.setContent(html_61c27f7b0250de7f8f7216232e68ad4c);
#
#
#
#         marker_744e80dcfce17b36ff3006ae36301480.bindPopup(popup_f34d389b466c4a87ae491744bcfd0b77)
#         ;
#
#
#
#
#             marker_744e80dcfce17b36ff3006ae36301480.bindTooltip(

# %%
df['color'] = ['red', 'blue', 'green', 'violet', 'orange']
df
# Out:
#        이름                             주소         위도          경도   color
# 0    영등포역  서울특별시 영등포구 경인로 지하843 (영등포동3가)  37.516463  126.906659     red
# 1    신도림역       서울특별시 구로구 경인로 625 (신도림동)  37.507084  126.884719    blue
# 2     당산역     서울특별시 영등포구 당산로 229 (당산동6가)  37.534957  126.902731   green
# 3    여의도역   서울특별시 영등포구 여의나루로 지하40 (여의도동)  37.521842  126.924485  violet
# 4  영등포구청역   서울특별시 영등포구 당산로 지하121 (당산동3가)  37.525700  126.896627  orange

# %%
map = folium.Map(location=[df.위도.mean(),df.경도.mean()], zoom_start=14) #Center position
for i in df.index:
    folium.Circle(
        location=[df.위도[i], df.경도[i]],
        tooltip=df.이름[i],
        popup=folium.Popup(df.주소[i], max_width=200),
        radius=100, color=df.color[i], fill=True
    ).add_to(map)
    folium.map.Marker(
        location=[df.위도[i], df.경도[i]],
        icon = folium.DivIcon(icon_size=(80, 20), icon_anchor=(20,0),
                              html=f'<span style="font-size: 10pt">{df.이름[i]}</span>')
    ).add_to(map)
folium.Marker(
    location=[df.위도.mean(),df.경도.mean()],
    icon=folium.CustomIcon('data/pushpin.jpg', icon_size=(30,30))
    ).add_to(map)

title_html = '<h3 align="center" style="font=size:20px">영등포소재 주요 지하철역</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d9b9408818be9c87605d73dc2757dcb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font=size:20px&quot;&gt;영등포소재 주요 지하철역&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d9b9408818be9c87605d73dc2757dcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d9b9408818be9c87605d73dc2757dcb = L.map(
#                 &quot;map_4d9b9408818be9c87605d73dc2757dcb&quot;,
#                 {
#                     center: [37.52120913312664, 126.9030439466804],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d54ceee0f4b9d7f1edcc82c561bf6041 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4d9b9408818be9c87605d73dc2757dcb);
#
#
#             var circle_9cfe8cbc31b3a35f08630dbaa355c2d8 = L.circle(
#                 [37.5164625580995, 126.906658750671],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4d9b9408818be9c87605d73dc2757dcb);
#
#
#         var popup_c8d88dc1d2b1d11199420d6b10a22acb = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_d52226c5683ddd7bed143423f92b23cd = $(`&lt;div id=&quot;html_d52226c5683ddd7bed143423f92b23cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 경인로 지하843 (영등포동3가)&lt;/div&gt;`)[0];
#                 popup_c8d88dc1d2b1d11199420d6b10a22acb.setContent(html_d52226c5683ddd7bed143423f92b23cd);
#
#
#
#         circle_9cfe8cbc31b3a35f08630dbaa355c2d8.bindPopup(popup_c8d88dc1d2b1d11199420d6b10a22acb)
#         ;
#
#
#
#
#             circle_9cfe8cbc31b3a35f08630dbaa355c2d8.bindTooltip(
#                 `&lt;div&gt;
#                      영등포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d2081fa09e43603dbbd3d2ac43cfeaa8 = L.marker(
#                 [37.5164625580995, 126.906658750671],
#                 {}
#             ).addTo(map_4d9b9408818be9c87605d73dc2757dcb);
#
#
#             var div_icon_b77fea74539e8f75871c72447e80a899 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan style=\&quot;font-size: 10pt\&quot;\u003e\uc601\ub4f1\ud3ec\uc5ed\u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [20, 0], &quot;iconSize&quot;: [80, 20]});
#             marker_d2081fa09e43603dbbd3d2ac43cfeaa8.setIcon(div_icon_b77fea74539e8f75871c72447e80a899);
#
#
#             var circle_ffd12d2e32570ef090640cf542e4dc4e = L.circle(
#                 [37.5070842748567, 126.884718686628],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4d9b9408818be9c87605d73dc2757dcb);
#
#
#         var popup_39d4a4912e32d5d7454becbf6add63ef = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_b87adf8d95ab92cdcc903c228fcb75bf = $(`&lt;div id=&quot;html_b87adf8d95ab92cdcc903c228fcb75bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 구로구 경인로 625 (신도림동)&lt;/div&gt;`)[0];
#                 popup_39d4a4912e32d5d7454becbf6add63ef.setContent(html_b87adf8d95ab92cdcc903c228fcb75bf);
#
#
#
#         circle_ffd12d2e32570ef090640cf542e4dc4e.bindPopup(popup_39d4a4912e32d5d7454becbf6add63ef)
#         ;
#
#
#
#
#             circle_ffd12d2e32570ef090640cf542e4dc4e.bindTooltip(
#                 `&lt;div&gt;
#                      신도림역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2dbfad9a3f6ce67a784aa4eaa0e6cb89 = L.marker(
#                 [37.5070842748567, 126.884718686628],
#                 {}
#             ).addTo(map_4d9b9408818be9c87605d73dc2757dcb);
#
#
#             var div_icon_bfc0a6a92b2520d0ea88cc655cba34b2 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan style=\&q
